# %%
# !python src/train_pred.py experiment=train_pred_SWET_ad_base.yaml

# %%
# !python src/manual_crop.py

# %%
import matplotlib.pyplot as plt

y = ['EczemaNet (ROI) SWET (Skin)', 'EczemaNet (ROI) SWET (AD)', 'EczemaNet (Seg.) SWET (Skin)', 'EczemaNet (Seg.) SWET (AD)']
x = [0.8728,0.5302,0.9234,0.8084]
x_err = [0.1451,0.4265,0.1766,0.3167]


plt.errorbar(x, y, ecolor='black', fmt='ok', xerr=x_err)
# plt.xlabel('SWET')

plt.grid(visible=True)
plt.axis(xmin = 0.0, xmax = 1.0)
plt.axis(ymin = -1, ymax = 4)
plt.tick_params(axis='both', labelsize=15)

plt.rcParams.update({'font.size': 13})

plt.title('Sensitivity')
plt.show()
# plt.savefig('IoU.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

y = ['EczemaNet (Pred.) SWET (nBG-Crop-Skin)', 'EczemaNet (Pred.) SWET (wBG-Whole)', 'ASCORAD (Pred.) SWET (nBG-Crop-Skin)', 'ASCORAD (Pred.) SWET (wBG-Whole)']
x = [1.9717,2.0297,1.9974,1.9778]
x_err = [0.1470,0.1592,0.1164,0.1541]


plt.errorbar(x, y, ecolor='black', fmt='ok', xerr=x_err)
# plt.xlabel('SWET')

plt.grid(visible=True)
plt.axis(xmin = 0.0, xmax = 1.0)
plt.axis(ymin = -1, ymax = 4)
plt.tick_params(axis='both', labelsize=15)

plt.rcParams.update({'font.size': 13})

plt.title('IoU')
plt.show()
# plt.savefig('IoU.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

y = ['EczemaNet (ROI) SWET (Skin)', 'EczemaNet (ROI) SWET (AD)', 'EczemaNet (Seg.) SWET (Skin)', 'EczemaNet (Seg.) SWET (AD)']
x = [0.7541, 0.6799, 0.7980, 0.8272]
x_err = [0.1394, 0.1394, 0.1394, 0.1394]


plt.errorbar(x, y, ecolor='black', fmt='ok', xerr=x_err)
# plt.xlabel('SWET')

plt.grid(visible=True)
plt.axis(xmin = 0.0, xmax = 1.0)
plt.axis(ymin = -1, ymax = 4)
plt.tick_params(axis='both', labelsize=15)

plt.rcParams.update({'font.size': 13})

plt.title('IoU')
plt.show()
# plt.savefig('IoU.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

y = ['EczemaNet (ROI) SWET (Skin)', 'EczemaNet (ROI) SWET (AD)', 'EczemaNet (Seg.) SWET (Skin)', 'EczemaNet (Seg.) SWET (AD)']
x = [0.7541, 0.6799, 0.7980, 0.8272]
x_err = [0.1394, 0.1394, 0.1394, 0.1394]


plt.errorbar(x, y, ecolor='black', fmt='ok', xerr=x_err)
# plt.xlabel('SWET')

plt.grid(visible=True)
plt.axis(xmin = 0.0, xmax = 1.0)
plt.axis(ymin = -1, ymax = 4)
plt.tick_params(axis='both', labelsize=15)

plt.rcParams.update({'font.size': 13})

plt.title('IoU')
plt.show()
# plt.savefig('IoU.png', bbox_inches='tight')
